# %%
import pickle

# result_objects_old: 64 epoch
# result_objects: 128 epoch

with open('result_objects_old.pkl', 'rb') as file:  # Open the file in binary read mode ('rb')
    result_objects = pickle.load(file)

# %%
result_objects
# Out:
# {'phobert': {'training_results': {'best_metrics': {'val/metrics/accuracy': 0.5254901960784314},
#    'patience': 6,
#    'history':     accuracy  macro_f1  macro_precision  macro_recall  epoch  step
#    0     0.3333    0.1677           0.1120        0.3333      0     4
#    1     0.4059    0.3129           0.2872        0.4059      1     9
#    2     0.4098    0.3186           0.2868        0.4098      2    14
#    3     0.4157    0.3290           0.2864        0.4157      3    19
#    4     0.3941    0.2837           0.3044        0.3941      4    24
#    ..       ...       ...              ...           ...    ...   ...
#    59    0.5196    0.4996           0.5006        0.5196     59   299
#    60    0.5176    0.4981           0.4987        0.5176     60   304
#    61    0.5216    0.5025           0.5029        0.5216     61   309
#    62    0.5235    0.5052           0.5056        0.5235     62   314
#    63    0.5196    0.5010           0.5006        0.5196     63   319
#
# ...

# %%
# {'phobert': {'training_results': {'best_metrics': {'val/metrics/accuracy': 0.5254901960784314},
#    'patience': 6,
#    'history':     accuracy  macro_f1  macro_precision  macro_recall  epoch  step
#    0     0.3333    0.1677           0.1120        0.3333      0     4
#    1     0.4059    0.3129           0.2872        0.4059      1     9
#    2     0.4098    0.3186           0.2868        0.4098      2    14
#    3     0.4157    0.3290           0.2864        0.4157      3    19
#    4     0.3941    0.2837           0.3044        0.3941      4    24
#    ..       ...       ...              ...           ...    ...   ...
#    59    0.5196    0.4996           0.5006        0.5196     59   299
#    60    0.5176    0.4981           0.4987        0.5176     60   304
#    61    0.5216    0.5025           0.5029        0.5216     61   309
#    62    0.5235    0.5052           0.5056        0.5235     62   314
#    63    0.5196    0.5010           0.5006        0.5196     63   319
   
#    [64 rows x 6 columns]},
#   'test_results': {'accuracy': 0.5009523809523809,
#    'macro_f1': 0.49000123642017196,
#    'macro_precision': 0.48563719308368974,
#    'macro_recall': 0.5009523809523809}},
#  'cnn': {'training_results': {'best_metrics': {'val/metrics/accuracy': 0.7196078431372549},
#    'patience': 8,
#    'history':     accuracy  macro_f1  macro_precision  macro_recall  epoch  step
#    0     0.3471    0.2013           0.5018        0.3471      0     4
#    1     0.4745    0.4000           0.6130        0.4745      1     9
#    2     0.5922    0.5893           0.6052        0.5922      2    14
#    3     0.6098    0.6108           0.6172        0.6098      3    19
#    4     0.5941    0.5830           0.6305        0.5941      4    24
#    ..       ...       ...              ...           ...    ...   ...
#    59    0.7118    0.7121           0.7135        0.7118     59   299
#    60    0.7118    0.7121           0.7135        0.7118     60   304
#    61    0.7118    0.7121           0.7135        0.7118     61   309
#    62    0.7118    0.7121           0.7135        0.7118     62   314
#    63    0.7118    0.7121           0.7135        0.7118     63   319
   
#    [64 rows x 6 columns]},
#   'test_results': {'accuracy': 0.7019047619047619,
#    'macro_f1': 0.7024435160430511,
#    'macro_precision': 0.7034471145120986,
#    'macro_recall': 0.7019047619047618}},
#  'lstm': {'training_results': {'best_metrics': {'val/metrics/accuracy': 0.6588235294117647},
#    'patience': 11,
#    'history':     accuracy  macro_f1  macro_precision  macro_recall  epoch  step
#    0     0.4235    0.3517           0.4986        0.4235      0     4
#    1     0.3882    0.2795           0.5881        0.3882      1     9
#    2     0.4196    0.3438           0.4717        0.4196      2    14
#    3     0.4098    0.3252           0.4993        0.4098      3    19
#    4     0.4765    0.4439           0.5443        0.4765      4    24
#    ..       ...       ...              ...           ...    ...   ...
#    59    0.6451    0.6453           0.6525        0.6451     59   299
#    60    0.6451    0.6454           0.6519        0.6451     60   304
#    61    0.6451    0.6454           0.6517        0.6451     61   309
#    62    0.6490    0.6492           0.6546        0.6490     62   314
#    63    0.6490    0.6492           0.6546        0.6490     63   319
   
#    [64 rows x 6 columns]},
#   'test_results': {'accuracy': 0.6342857142857142,
#    'macro_f1': 0.6343072623789854,
#    'macro_precision': 0.6355548412300841,
#    'macro_recall': 0.6342857142857143}},
#  'hybrid_crnn': {'training_results': {'best_metrics': {'val/metrics/accuracy': 0.6980392156862745},
#    'patience': 36,
#    'history':     accuracy  macro_f1  macro_precision  macro_recall  epoch  step
#    0     0.3784    0.2577           0.3073        0.3784      0     4
#    1     0.3333    0.1667           0.1111        0.3333      1     9
#    2     0.3529    0.2117           0.3798        0.3529      2    14
#    3     0.4725    0.3725           0.3595        0.4725      3    19
#    4     0.4647    0.3712           0.3515        0.4647      4    24
#    ..       ...       ...              ...           ...    ...   ...
#    59    0.6804    0.6810           0.6827        0.6804     59   299
#    60    0.6824    0.6827           0.6842        0.6824     60   304
#    61    0.6843    0.6848           0.6868        0.6843     61   309
#    62    0.6843    0.6848           0.6868        0.6843     62   314
#    63    0.6863    0.6867           0.6889        0.6863     63   319
   
#    [64 rows x 6 columns]},
#   'test_results': {'accuracy': 0.680952380952381,
#    'macro_f1': 0.6827848398488762,
#    'macro_precision': 0.6909139055531958,
#    'macro_recall': 0.6809523809523809}}}

# %%
# import matplotlib.pyplot as plt

# def draw_metrics_chart(metrics, method_names):
#     """
#     Draws a metrics chart for each method.

#     Parameters:
#     metrics (dict): A dictionary where keys are metric names and values are lists of metric values for each method.
#     method_names (list): A list of method names.

#     Example:
#     metrics = {
#         'accuracy': [0.9, 0.85, 0.88, 0.87],
#         'precision': [0.8, 0.75, 0.78, 0.77],
#         'recall': [0.85, 0.8, 0.83, 0.82]
#     }
#     method_names = ['Method A', 'Method B', 'Method C', 'Method D']
#     """
#     num_metrics = len(metrics)
#     fig, axes = plt.subplots(1, num_metrics, figsize=(15, 5))

#     for i, (metric, values) in enumerate(metrics.items()):
#         axes[i].bar(method_names, values)
#         axes[i].set_title(metric)
#         axes[i].set_ylim(0, 1)
#         axes[i].set_ylabel('Score')

#     plt.tight_layout()
#     plt.show()
    
# # Extract the metrics from the result_objects
# metrics = {}
# for method_name, method_results in result_objects.items():
#     metrics[method_name] = {
#         'accuracy': method_results['test_results']['accuracy'],
#         'macro_f1': method_results['test_results']['macro_f1'],
#         'macro_precision': method_results['test_results']['macro_precision'],
#         'macro_recall': method_results['test_results']['macro_recall']
#     }
    
# # Draw the metrics chart
# draw_metrics_chart(metrics, list(result_objects.keys()))

# %%
result_objects['phobert']['test_results'] 
# {'accuracy': 0.5009523809523809,
#  'macro_f1': 0.49000123642017196,
#  'macro_precision': 0.48563719308368974,
#  'macro_recall': 0.5009523809523809}


# draw the training history 
def draw_training_history(result_objects):
    import matplotlib.pyplot as plt

    num_methods = len(result_objects)
    fig, axes = plt.subplots(num_methods, 1, figsize=(15, 5*num_methods))

    for i, (method_name, method_results) in enumerate(result_objects.items()):
        history = method_results['training_results']['history']
        axes[i].plot(history['epoch'], history['accuracy'], label='accuracy')
        axes[i].plot(history['epoch'], history['macro_f1'], label='macro_f1')
        axes[i].plot(history['epoch'], history['macro_precision'], label='macro_precision')
        axes[i].plot(history['epoch'], history['macro_recall'], label='macro_recall')
        # axes[i].set_title(method_name)
        
        # Title is training history of model
        axes[i].set_title(f'Training history of {method_name}')
        
        axes[i].set_xlabel('Epoch')
        axes[i].set_ylabel('Validation Result of Validation Set')
        axes[i].legend()

    plt.tight_layout()
    # plt.show()
    
    # save the figure
    plt.savefig('training_history.png')
    


    
draw_training_history(result_objects)

# %%
# def show_compared_test_table(result_objects):
#     import pandas as pd

#     test_results = []
#     for method_name, method_results in result_objects.items():
#         test_results.append([
#             method_name,
#             method_results['test_results']['accuracy'],
#             method_results['test_results']['macro_f1'],
#             method_results['test_results']['macro_precision'],
#             method_results['test_results']['macro_recall']
#         ])

#     test_results = pd.DataFrame(test_results, columns=['Method', 'Accuracy', 'Macro F1', 'Macro Precision', 'Macro Recall'])
#     # round the values to 4 decimal places
#     test_results = test_results.round(4)
    
    
#     display(test_results)
    
# show_compared_test_table(result_objects)


def show_compared_test_table_prettytable(result_objects):
    import prettytable

    table = prettytable.PrettyTable()
    table.field_names = ['Method', 'Accuracy', 'Macro F1', 'Macro Precision', 'Macro Recall']

    for method_name, method_results in result_objects.items():
        test_results = method_results['test_results']
        table.add_row([
            method_name,
            f'{test_results["accuracy"]:.4f}',
            f'{test_results["macro_f1"]:.4f}',
            f'{test_results["macro_precision"]:.4f}',
            f'{test_results["macro_recall"]:.4f}'
        ])
    print(table)
    # write the table to a text file
    with open('test_results.txt', 'w') as file:
        file.write(str(table))
    
show_compared_test_table_prettytable(result_objects)
# Out:
# +-------------+----------+----------+-----------------+--------------+
# |    Method   | Accuracy | Macro F1 | Macro Precision | Macro Recall |
# +-------------+----------+----------+-----------------+--------------+
# |   phobert   |  0.5010  |  0.4900  |      0.4856     |    0.5010    |
# |     cnn     |  0.7019  |  0.7024  |      0.7034     |    0.7019    |
# |     lstm    |  0.6343  |  0.6343  |      0.6356     |    0.6343    |
# | hybrid_crnn |  0.6810  |  0.6828  |      0.6909     |    0.6810    |
# +-------------+----------+----------+-----------------+--------------+
